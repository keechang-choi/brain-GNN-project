# %%
import torch
from torch_geometric.data import Data
import pandas as pd
import os

# %%
df = pd.read_excel('../data/DT_File_MAP.xlsx')
df
# Out:
#      Subject        PTID  VISCODE LABEL   AGE  GENDER  EDUCATION  Node 1  \
# 0    S177586  005_S_4910        3    AD  81.4  Female         15   1.959
# 1    S185876  005_S_4910        6    AD  81.4  Female         15   1.891
# 2    S177601  005_S_5038        0    AD  81.5    Male         18   2.025
# 3    S184500  005_S_5038        3    AD  81.5    Male         18   2.016
# 4    S191604  005_S_5038        6    AD  81.5    Male         18   2.004
# ..       ...         ...      ...   ...   ...     ...        ...     ...
# 495  S155271  098_S_4506        3    CN  71.5    Male         19   2.140
# 496  S167381  098_S_4506        6    CN  71.5    Male         19   2.145
# 497  S197407  098_S_4506       12    CN  71.5    Male         19   1.990
# 498  S447003  098_S_4506       24    CN  71.5    Male         19   2.134
# 499  S206831  129_S_4371       24    CN  67.7    Male         18   2.306
#
#      Node 2  Node 3  ...  Node 139  Node 140  Node 141  Node 142  Node 143  \
# 0     2.047   2.108  ...     1.847     2.070     1.573     1.998     2.193
# 1     2.048   1.783  ...     1.649     2.271     1.594     1.793     2.240
# 2     2.048   2.507  ...     1.878     2.044     1.886     2.367     2.156
# 3     1.964   2.572  ...     1.859     2.042     1.784     2.200     2.004
# 4     1.907   2.411  ...     1.764     2.077     1.768     2.229     2.049
# ..      ...     ...  ...       ...       ...       ...       ...       ...
# 495   2.143   2.061  ...     1.846     2.541     1.814     2.181     2.360
# 496   2.182   2.005  ...     1.831     2.606     1.873     2.239     2.363
# 497   2.174   2.038  ...     1.781     2.498     1.771     2.177     2.094
# 498   2.171   2.012  ...     1.820     2.558     1.769     2.204     2.140
# 499   2.337   1.972  ...     1.895     2.554     1.691     2.102     1.895
#
#      Node 144  Node 145  Node 146  Node 147  Node 148
# 0       1.976     1.733     1.574     1.838     1.457
# 1       2.562     1.647     1.642     1.837     1.541
# 2       2.163     2.215     2.112     2.066     1.830
# 3       1.904     2.170     1.681     1.929     1.637
# 4       1.900     2.224     2.103     2.014     1.788
# ..        ...       ...       ...       ...       ...
# 495     1.885     2.007     2.226     2.202     2.314
# 496     2.511     1.992     2.298     2.181     2.171
# 497     2.399     1.995     2.333     2.185     2.097
# 498     2.405     2.056     2.368     2.165     1.959
# 499     2.416     1.970     1.954     2.020     1.987
#
# [500 rows x 155 columns]

# %%
df[df.index==0]["LABEL"].item()
# Out:
# 'AD'

# %%
labels = {}
labels['CN'] = 0
labels['EMCI'] = 1
labels['LMCI'] = 2
labels['AD'] = 3
# Out:
# 3

# %%
df.shape[0]
# Out:
# 500

# %%
filepath_r = os.path.join(os.path.join(".","sparsifiaction"),"data")
filepath_r = "./sparsification/data"

# %%
datalist = []
for i in range(df.shape[0]):
    print(df[df.index==i]["LABEL"].item())
    label = df[df.index==i]["LABEL"].item()
    if(label == 'SMC' or label == 'EMCI' or label == 'LMCI'):
        continue
    y = labels[label]
    filename = os.path.join(filepath_r, "%s_fdt_network_matrix_df.csv"%df[df.index==i]["Subject"].item())
    #print(filename)
    
    edge_table = pd.read_csv(filename, sep = "\t")
    edge_table = edge_table[["src", "trg", "nij"]]
    #print(edge_table)
    edge_index = torch.tensor(edge_table[["src", "trg"]].values).transpose(0,1)
    edge_attr = torch.tensor(edge_table[["nij"]].values, dtype=torch.float)
    #print(edge_index.size())
    #print(edge_attr.size())
           
    x = torch.tensor(df[df.index==i][["Node %d"%(i) for i in range(1,149)]].values,  dtype=torch.float).transpose(0,1)
    #print(x.size())
    data = Data(x=x, y=y, edge_index=edge_index, edge_attr=edge_attr)
    datalist.append(data)
    #break
# Out:
# AD
# AD
# AD
# AD
# AD
# AD
# AD
# AD
# AD
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# CN
# CN
# CN
# CN
# EMCI
# EMCI
# EMCI
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# AD
# AD
# AD
# LMCI
# LMCI
# LMCI
# LMCI
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# AD
# AD
# AD
# AD
# AD
# SMC
# SMC
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# AD
# AD
# AD
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# AD
# AD
# LMCI
# LMCI
# LMCI
# LMCI
# AD
# AD
# AD
# AD
# EMCI
# EMCI
# CN
# CN
# CN
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# CN
# CN
# CN
# AD
# AD
# AD
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# AD
# AD
# AD
# AD
# AD
# AD
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# LMCI
# LMCI
# LMCI
# LMCI
# CN
# CN
# CN
# EMCI
# EMCI
# EMCI
# EMCI
# AD
# AD
# AD
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# LMCI
# LMCI
# LMCI
# EMCI
# EMCI
# SMC
# SMC
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# AD
# AD
# AD
# AD
# AD
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# LMCI
# LMCI
# LMCI
# LMCI
# AD
# AD
# AD
# LMCI
# LMCI
# LMCI
# LMCI
# AD
# AD
# AD
# AD
# AD
# AD
# EMCI
# EMCI
# EMCI
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# EMCI
# CN
# CN
# CN
# AD
# EMCI
# CN
# CN
# CN
# CN
# CN
# EMCI
# EMCI
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# AD
# AD
# AD
# AD
# AD
# AD
# AD
# AD
# EMCI
# EMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# EMCI
# EMCI
# EMCI
# EMCI
# LMCI
# LMCI
# LMCI
# LMCI
# SMC
# SMC
# SMC
# SMC
# SMC
# SMC
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# AD
# AD
# AD
# AD
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# LMCI
# CN
# CN
# CN
# CN
# CN
# CN
# AD
# AD
# AD
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# LMCI
# LMCI
# LMCI
# LMCI
# CN
# CN
# CN
# CN
# AD
# AD
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# EMCI
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# EMCI
# EMCI
# EMCI
# EMCI
# AD
# AD
# AD
# AD
# AD
# AD
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN
# CN

# %%
torch.tensor(edge_table[["src", "trg"]].values)
torch.tensor(df[df.index==i][["Node %d"%(i) for i in range(1,149)]].values)
# Out:
# tensor([[2.3060, 2.3370, 1.9720, 2.6110, 2.2580, 2.5760, 2.5800, 2.2300, 2.7630,
#          2.8050, 1.7890, 2.6430, 2.7980, 2.6330, 2.2490, 2.3300, 3.3290, 3.6430,
#          2.3350, 1.8910, 2.6510, 1.8240, 2.8110, 2.4500, 2.1070, 2.0860, 1.9190,
#          1.8790, 2.3670, 2.2990, 2.4260, 3.3450, 2.2900, 2.6160, 3.0150, 2.2840,
#          2.8370, 2.6600, 2.3310, 2.6130, 2.0850, 1.7320, 2.9130, 1.7850, 1.6220,
#          2.0700, 2.6230, 2.4450, 2.3610, 2.4540, 1.6740, 1.9320, 1.8900, 1.7520,
#          1.7530, 1.6870, 1.7050, 1.8410, 2.0100, 2.1670, 2.0500, 1.8980, 2.0690,
#          2.2330, 2.0130, 3.1550, 1.8930, 2.1960, 1.9330, 2.1960, 2.1820, 2.3530,
#          2.1730, 2.0010, 2.5210, 1.9080, 2.0060, 2.3470, 2.2650, 2.4190, 2.3500,
#          2.3640, 2.8940, 2.9030, 1.9470, 2.4320, 2.5880, 2.4960, 2.3190, 2.4460,
#          2.9330, 3.2040, 2.2710, 1.9980, 2.5780, 1.8190, 3.0360, 2.4580, 2.2040,
#          2.3290, 1.9530, 1.6860, 2.2580, 2.2320, 2.4180, 2.1000, 2.1330, 2.6370,
#          3.0530, 2.0240, 2.7750, 2.7470, 1.6410, 1.8720, 2.0210, 1.6680, 3.1540,
#          1.7020, 1.5390, 1.9500, 2.6250, 2.6810, 2.3430, 2.6930, 1.7300, 2.0180,
#          1.9270, 1.9770, 1.6210, 1.7840, 1.5210, 1.5950, 2.0960, 2.4130, 2.0200,
#          1.5750, 1.8930, 2.1130, 1.8950, 2.5540, 1.6910, 2.1020, 1.8950, 2.4160,
#          1.9700, 1.9540, 2.0200, 1.9870]], dtype=torch.float64)

# %%
len(datalist)
# Out:
# 441

# %%
188*0.8
# Out:
# 150.4

# %%
#dataset = datalist
train_len = int(len(datalist)*0.8)
torch.manual_seed(12345)
#dataset = dataset.shuffle()

#train_dataset = dataset[:train_len]
#test_dataset = dataset[train_len:]

train_dataset, test_dataset = torch.utils.data.random_split(datalist, [train_len, len(datalist) -train_len])

print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# Number of training graphs: 352
# Number of test graphs: 89

# %%
from torch_geometric.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[9472], edge_attr=[72736, 1], edge_index=[2, 72736], x=[9472, 1], y=[64])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[9472], edge_attr=[72543, 1], edge_index=[2, 72543], x=[9472, 1], y=[64])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[9472], edge_attr=[74159, 1], edge_index=[2, 74159], x=[9472, 1], y=[64])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[9472], edge_attr=[73567, 1], edge_index=[2, 73567], x=[9472, 1], y=[64])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[9472], edge_attr=[73929, 1], edge_index=[2, 73929], x=[9472, 1], y=[64])
#
# Step 6:
# =======
# Number of graphs in the current batch: 32
# Batch(batch=[4736], edge_attr=[35824, 1], edge_index=[2, 35824], x=[4736, 1], y=[32])

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool

num_node_features =  1
num_classes = 4
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(num_node_features, hidden_channels, add_self_loops = False, nor)
        self.conv2 = GCNConv(hidden_channels, hidden_channels, add_self_loops = False)
        self.conv3 = GCNConv(hidden_channels, hidden_channels, add_self_loops = False)
        self.lin = Linear(hidden_channels, num_classes)

    def forward(self, x, edge_index, edge_attr, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index, edge_attr)
        x = x.relu()
        x = self.conv2(x, edge_index, edge_attr)
        x = x.relu()
        x = self.conv3(x, edge_index, edge_attr)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

model = GCN(hidden_channels=64)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(1, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=4, bias=True)
# )

# %%
#from IPython.display import Javascript
#display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

model = GCN(hidden_channels=64)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
        #print(data.x, data.edge_index, data.batch)
        out = model(data.x, data.edge_index,data.edge_attr, data.batch)  # Perform a single forward pass.
        loss = criterion(out, data.y)  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.

def test(loader):
    model.eval()

    correct = 0
    for data in loader:  # Iterate in batches over the training/test dataset.
        out = model(data.x, data.edge_index,data.edge_attr, data.batch)  
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        correct += int((pred == data.y).sum())  # Check against ground-truth labels.
    return correct / len(loader.dataset)  # Derive ratio of correct predictions.


for epoch in range(1, 201):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.3636, Test Acc: 0.3820
# Epoch: 002, Train Acc: 0.3636, Test Acc: 0.3820
# Epoch: 003, Train Acc: 0.3636, Test Acc: 0.3820
# Epoch: 004, Train Acc: 0.3636, Test Acc: 0.3820
# Epoch: 005, Train Acc: 0.3636, Test Acc: 0.3820
# Epoch: 006, Train Acc: 0.3636, Test Acc: 0.3820
# Epoch: 007, Train Acc: 0.3636, Test Acc: 0.3820
# Epoch: 008, Train Acc: 0.3636, Test Acc: 0.3820
# Epoch: 009, Train Acc: 0.3636, Test Acc: 0.3820
# Epoch: 010, Train Acc: 0.3636, Test Acc: 0.3820
# Epoch: 011, Train Acc: 0.3636, Test Acc: 0.3820
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-138-f9e29473b1c1> in <module>
#      29
#      30 for epoch in range(1, 201):
# ---> 31     train()
#      32     train_acc = test(train_loader)
#      33     test_acc = test(test_loader)
#
# <ipython-input-138-f9e29473b1c1> in train()
#      11     for data in train_loader:  # Iterate in batches over the training dataset.
#      12         #print(data.x, data.edge_index, data.batch)
# ---> 13         out = model(data.x, data.edge_index,data.edge_attr, data.batch)  # Perform a single forward pass.
#      14         loss = criterion(out, data.y)  # Compute the loss.
#      15         loss.backward()  # Derive gradients.
#
# ~\Anaconda3\envs\graph_matching\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-137-f3eec360ec8f> in forward(self, x, edge_index, edge_attr, batch)
#      24
#      25         # 2. Readout layer
# ---> 26         x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]
#      27
#      28         # 3. Apply a final classifier
#
# ~\Anaconda3\envs\graph_matching\lib\site-packages\torch_geometric\nn\glob\glob.py in global_mean_pool(x, batch, size)
#      47
#      48     size = int(batch.max().item() + 1) if size is None else size
# ---> 49     return scatter(x, batch, dim=0, dim_size=size, reduce='mean')
#      50
#      51
#
# ~\Anaconda3\envs\graph_matching\lib\site-packages\torch_scatter\scatter.py in scatter(src, index, dim, out, dim_size, reduce)
#     152         return scatter_sum(src, index, dim, out, dim_size)
#     153     elif reduce == 'mean':
# --> 154         return scatter_mean(src, index, dim, out, dim_size)
#     155     elif reduce == 'min':
#     156         return scatter_min(src, index, dim, out, dim_size)[0]
#
# KeyboardInterrupt:
